# %% [markdown]
# **015017**
# **UMANG DHAR DWIVEDI**
# **HUGGING FACE Question Answer Project**🤗

# %%
# !pip install -q transformers==4.4.2

# %%
import torch
torch.__version__
# Out:
# '1.10.0+cu111'

# %%
# !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# Out:
# Looking in links: https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# Collecting torch-scatter
#   Downloading torch_scatter-2.0.9.tar.gz (21 kB)
# Building wheels for collected packages: torch-scatter
#   Building wheel for torch-scatter (setup.py) ... done
#   Created wheel for torch-scatter: filename=torch_scatter-2.0.9-cp37-cp37m-linux_x86_64.whl size=282114 sha256=7b5bfe70f60b7e0e9c10977e5c9d4e19008ab0f334f8ac42a10343730cd2dcfe
#   Stored in directory: /root/.cache/pip/wheels/dd/57/a3/42ea193b77378ce634eb9454c9bc1e3163f3b482a35cdee4d1
# Successfully built torch-scatter
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.0.9

# %%
from transformers import pipeline
import pandas as pd

# %%
tqa = pipeline(task="table-question-answering", 
               model="google/tapas-base-finetuned-wtq")
# Out:
# Downloading:   0%|          | 0.00/1.66k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/443M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/262k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/154 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/490 [00:00<?, ?B/s]

# %%
cric = pd.read_csv("/content/data.csv")
cric = cric.astype(str)

# %%
cric.head(10)
# Out:
#   Pos              Player          Team  ... Highest Score Average Strike Rate
# 0   1    Sachin Tendulkar         India  ...           200   44.83       86.23
# 1   2    Kumar Sangakkara     Sri Lanka  ...           169   41.98       78.86
# 2   3       Ricky Ponting     Australia  ...           164   42.03       80.39
# 3   4   Sanath Jayasuriya     Sri Lanka  ...           189   32.36        91.2
# 4   5  Mahela Jayawardene     Sri Lanka  ...           144   33.37       78.96
# 5   6         Virat Kohli         India  ...           183   59.85       93.39
# 6   7      Inzamam-ul-Haq      Pakistan  ...           137   39.52       74.24
# 7   8      Jacques Kallis  South Africa  ...           139   44.36       72.89
# 8   9      Saurav Ganguly         India  ...           183   41.02        73.7
# 9  10        Rahul Dravid         India  ...           153   39.16       71.24
#
# [10 rows x 9 columns]

# %%
query = "Who has scored the lowest score?"
print(tqa(table=table, query=query)["answer"])
# Out:
# Inzamam-ul-Haq

# %%
query = ["Virat Kohli's highest score?", 
         "Which team does he play for?"]
answer = tqa(table=table, query=query)
for ans in answer:
    print(ans["answer"])
# Out:
# AVERAGE > 183
# India

# %%
query = "Who is the best player?"
print(tqa(table=table, query=query)["answer"])
# Out:
# Sachin Tendulkar

# %%
query = "Who is the best player?"
print(tqa(table=table, query=query)["answer"])
# Out:
# Sachin Tendulkar

# %%
query = ["Who has played most Innings?",
         "Number of maximum innings"]
answer = tqa(table=table, query=query)
for ans in answer:
    print(ans["answer"])
# Out:
# Sachin Tendulkar
# AVERAGE > 452

# %%
query = "What are maximum runs scored?"
print(tqa(table=table, query=query)["answer"])
# Out:
# AVERAGE > 18426

# %%
query = "Who has the maximum average?"
print(tqa(table=table, query=query)["answer"])
# Out:
# Virat Kohli

# %% [markdown]
# **THANKS**
# **DO VISIT REMAING PROJECTS IN SAME REPOSITORY**
